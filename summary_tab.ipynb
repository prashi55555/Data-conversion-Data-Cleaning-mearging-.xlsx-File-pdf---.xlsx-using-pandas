# %%
import pandas as pd
path = "F:/8th sem/Cleaning of Data & Merging into single excel/Payout Summary & Order Level Sales/invoice_Annexure_408_09042025_1744207092917.xlsx"
df = pd.read_excel(path, sheet_name='Summary')
fn = path[91:139]

# %%
df
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN                                                NaN
# 1          NaN                                                NaN
# 2          NaN                                                NaN
# 3          NaN                                      Alpha Biryani
# 4          NaN                                         Whitefield
# 5          NaN                                          Bangalore
# 6          NaN                                     Rest. ID - 408
# 7          NaN                           GSTIN  - 29ABNFM9601R1Z9
# 8          NaN                                                NaN
# 9          NaN                                Your Payout Details
# 10         NaN                                      Payout Period
# 11         NaN                             Payout Settlement Date
# 12         NaN                                       Total Payout
# ...

# %%
df = df.drop(df.index[15:27]) 
df = df.drop(df.index[7:10])

# %%
df = df.drop(df.index[0:3])

# %%
df = df.T

# %%
df
# Out:
#                        3           4          5               6   \
# Unnamed: 0            NaN         NaN        NaN             NaN
# Unnamed: 1  Alpha Biryani  Whitefield  Bangalore  Rest. ID - 408
# Unnamed: 2            NaN         NaN        NaN             NaN
#
#                              10                      11            12  \
# Unnamed: 0                  NaN                     NaN           NaN
# Unnamed: 1        Payout Period  Payout Settlement Date  Total Payout
# Unnamed: 2  01 April - 05 April                08 April     ₹6818.6
#
#                                               13                  14
# Unnamed: 0                                   NaN                 NaN
# Unnamed: 1  Total Orders (Delivered + Cancelled)            Bank UTR
# Unnamed: 2                                  26    AXISCN0957979233

# %%
df.iat[0, 0] = 'Brand'  
df.iat[0,1] = 'Location'
df.iat[0,2] = 'City'
df.iat[0,3] = 'Res-Id'
df.iat[0,4] = 'Payout Period'
df.iat[0,5] = 'Payout Settlement Date'
df.iat[0,6] = 'Total Payout'
df.iat[0,7] = 'Total Orders (Delivered + Cancelled)'
df.iat[0,8] = 'Bank UTR'
df.iat[1,4] = df.iat[2,4]
df.iat[2,4] = 0
df.iat[1,5] = df.iat[2,5]
df.iat[2,5] = 0
df.iat[1,6] = df.iat[2,6]
df.iat[2,6] = 0
df.iat[1,7] = df.iat[2,7]
df.iat[2,7] = 0
df.iat[1,8] = df.iat[2,8]
df.iat[2,8] = 0

# %%
df
# Out:
#                        3           4          5               6   \
# Unnamed: 0          Brand    Location       City          Res-Id
# Unnamed: 1  Alpha Biryani  Whitefield  Bangalore  Rest. ID - 408
# Unnamed: 2            NaN         NaN        NaN             NaN
#
#                              10                      11            12  \
# Unnamed: 0        Payout Period  Payout Settlement Date  Total Payout
# Unnamed: 1  01 April - 05 April                08 April     ₹6818.6
# Unnamed: 2                    0                       0             0
#
#                                               13                  14
# Unnamed: 0  Total Orders (Delivered + Cancelled)            Bank UTR
# Unnamed: 1                                  26    AXISCN0957979233
# Unnamed: 2                                     0                   0

# %%
df = df.drop(df.index[2])

# %%
df.columns = df.iloc[0]   
df = df[1:].reset_index(drop=True)

# %%
df["FileName"]=fn

# %%
df.columns
# Out:
# Index(['Brand', 'Location', 'City', 'Res-Id', 'Payout Period',
#        'Payout Settlement Date', 'Total Payout',
#        'Total Orders (Delivered + Cancelled)', 'Bank UTR', 'FileName'],
#       dtype='object', name='Unnamed: 0')

# %%
df.to_excel("F:/8th sem/Cleaning of Data & Merging into single excel/Summary.xlsx", index=False)

# %%
df
# Out:
# Unnamed: 0          Brand    Location       City          Res-Id  \
# 0           Alpha Biryani  Whitefield  Bangalore  Rest. ID - 408
#
# Unnamed: 0        Payout Period Payout Settlement Date Total Payout  \
# 0           01 April - 05 April               08 April    ₹6818.6
#
# Unnamed: 0 Total Orders (Delivered + Cancelled)            Bank UTR  \
# 0                                          26    AXISCN0957979233
#
# Unnamed: 0                                          FileName
# 0           invoice_Annexure_408_09042025_1744207092917.xlsx

# %%
import pandas as pd
source_df = pd.read_excel("F:/8th sem/Cleaning of Data & Merging into single excel/Summary.xlsx", sheet_name=0)
target_df = pd.read_excel("F:/8th sem/Cleaning of Data & Merging into single excel/Data Analyst Quick Assignment.xlsx", sheet_name='Summary')

for col in source_df.columns:
    if col in target_df.columns:
        target_df[col] = target_df[col].combine_first(source_df[col])

target_df.to_excel("target_filled.xlsx", index=False)
# Out:
# C:\Users\Prashanth\AppData\Local\Temp\ipykernel_32456\3112455470.py:7: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   target_df[col] = target_df[col].combine_first(source_df[col])

# %%
df1 = pd.read_excel("target_filled.xlsx")
df1
# Out:
#            Brand    Location       City          Res-Id        Payout Period  \
# 0  Alpha Biryani  Whitefield  Bangalore  Rest. ID - 408  01 April - 05 April
#
#   Payout Settlement Date Total Payout  Total Orders (Delivered + Cancelled)  \
# 0               08 April    ₹6818.6                                      26
#
#              Bank UTR
# 0  AXISCN0957979233

# %%
df1 = pd.read_excel("F:/8th sem/Cleaning of Data & Merging into single excel/Data Analyst Quick Assignment.xlsx", sheet_name='Summary')
df2 = pd.read_excel("F:/8th sem/Cleaning of Data & Merging into single excel/Summary.xlsx", sheet_name=0)

combined_df = pd.concat([df1, df2], ignore_index=True)
df3 = combined_df.to_excel("combined_output.xlsx", index=False)

# %%
df3 = pd.read_excel("combined_output.xlsx")

# %%
df3
# Out:
#            Brand    Location       City          Res-Id        Payout Period  \
# 0  Alpha Biryani  Whitefield  Bangalore  Rest. ID - 408  01 April - 05 April
#
#   Payout Settlement Date Total Payout  Total Orders (Delivered + Cancelled)  \
# 0               08 April    ₹6818.6                                      26
#
#              Bank UTR                                          FileName
# 0  AXISCN0957979233    invoice_Annexure_408_09042025_1744207092917.xlsx

# %%
df.to_excel("F:/8th sem/Cleaning of Data & Merging into single excel/cleaned payout & summary files/summary.xlsx files/summary.xlsx", index=False)
