# %%
import pandas as pd
df = pd.read_excel("F:/8th sem/Cleaning of Data & Merging into single excel/cleaned payout & summary files/summary.xlsx files/Summary.xlsx", sheet_name=0)

# %%
df
# Out:
#            Brand    Location       City          Res-Id        Payout Period  \
# 0  Alpha Biryani  Whitefield  Bangalore  Rest. ID - 408  01 April - 05 April
#
#   Payout Settlement Date Total Payout  Total Orders (Delivered + Cancelled)  \
# 0               08 April    ₹6818.6                                      26
#
#              Bank UTR                                          FileName
# 0  AXISCN0957979233    invoice_Annexure_408_09042025_1744207092917.xlsx

# %%
columns_names = ['City', 'Location', 'Payout Settlement Date', 'Total Orders (Delivered + Cancelled)', 'Bank UTR']
df = df.drop(columns=columns_names)

# %%
path = "F:/8th sem/Cleaning of Data & Merging into single excel/Payout Summary & Order Level Sales/invoice_Annexure_408_09042025_1744207092917.xlsx"
df1 = pd.read_excel(path, sheet_name='Payout Breakup')
df1
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN  Payout Breakup\nBreakup of your total earnings...
# 1          NaN                                                NaN
# 2          NaN                                                NaN
# 3          NaN                                                  A
# 4          NaN                                                  1
# 5          NaN                                                  2
# 6          NaN                                                  3
# 7          NaN                                                  4
# 8          NaN                                                NaN
# 9          NaN                                                  B
# 10         NaN                                                  6
# 11         NaN                                                  7
# 12         NaN                                                  8
# ...

# %%
df1 = df1.drop(df1.index[3:33])
df1 = df1.drop(0)
df1 = df1.T
df1
# Out:
#                            1       2
# Unnamed: 0               NaN     NaN
# Unnamed: 1               NaN     NaN
# Unnamed: 2       Particulars  Orders
# Unnamed: 3  Delivered Orders      26
# Unnamed: 4  Cancelled Orders       0
# Unnamed: 5             Total      26

# %%
df1 = df1.drop(df1.index[0:2])
df1 = df1.T 
df1
# Out:
#     Unnamed: 2        Unnamed: 3        Unnamed: 4 Unnamed: 5
# 1  Particulars  Delivered Orders  Cancelled Orders      Total
# 2       Orders                26                 0         26

# %%
df1.columns = df1.iloc[0]   
df1 = df1[1:].reset_index(drop=True)
df1
# Out:
# 1 Particulars Delivered Orders Cancelled Orders Total
# 0      Orders               26                0    26

# %%
df2 = pd.concat([df1, df], ignore_index=True)

# %%
df2
# Out:
#   Particulars Delivered Orders Cancelled Orders Total          Brand  \
# 0      Orders               26                0    26            NaN
# 1         NaN              NaN              NaN   NaN  Alpha Biryani
#
#            Res-Id        Payout Period Total Payout  \
# 0             NaN                  NaN          NaN
# 1  Rest. ID - 408  01 April - 05 April    ₹6818.6
#
#                                            FileName
# 0                                               NaN
# 1  invoice_Annexure_408_09042025_1744207092917.xlsx

# %%
df2.iat[0,4] = df2.iat[1,4]
df2.iat[1,4] = 0
df2.iat[0,5] = df2.iat[1,5]
df2.iat[1,5] = 0
df2.iat[0,6] = df2.iat[1,6]
df2.iat[1,6] = 0
df2.iat[0,7] = df2.iat[1,7]
df2.iat[1,7] = 0
df2.iat[0,8] = df2.iat[1,8]
df2.iat[1,8] = 0
df2 = df2.drop(df2.index[1])
df2
# Out:
#   Particulars Delivered Orders Cancelled Orders Total          Brand  \
# 0      Orders               26                0    26  Alpha Biryani
#
#            Res-Id        Payout Period Total Payout  \
# 0  Rest. ID - 408  01 April - 05 April    ₹6818.6
#
#                                            FileName
# 0  invoice_Annexure_408_09042025_1744207092917.xlsx

# %%
df2.to_excel("F:/8th sem/Cleaning of Data & Merging into single excel/cleaned payout & summary files/payout break out.xlsx files/payout break.xlsx", index=False)
